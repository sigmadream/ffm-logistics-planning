# %% [markdown]
# # 주문 내역 생성

# %% [markdown]
# ## 1.라이브러리 설치

# %%
#pip install openpyxl
# L pip install --upgrade pip
#pip install pandas

# %%
import pandas as pd
import numpy as np
import string
import openpyxl
import random

# %% [markdown]
# ## 2. 주문 내역 생성 모듈 INPUT 값(변수)
#
# 1) 주문 내역 수(1개월 기준) - default 10000개
# 2) 필요시 분포(?) - 미정

# %% [markdown]
# ## 3. 램덤 주문 내역 생성(sample)

# %%
# 특성 1 ~ 20 생성
val_1 = np.random.randint(0, 10000,size = 10000)
val_2 = np.random.randint(10000, 20000, size = 10000)
val_3 = np.random.randint(20000, 30000, size = 10000)
val_4 = np.random.randint(30000, 40000, size = 10000)
val_5 = np.random.randint(40000, 50000, size = 10000)
val_6 = np.random.randint(50000, 60000, size = 10000)
val_7 = np.random.randint(60000, 70000, size = 10000)
val_8 = np.random.randint(70000, 80000, size = 10000)
val_9 = np.random.randint(80000, 90000, size = 10000)
val_10 = np.random.randint(90000, 100000, size = 10000)
val_11 = np.random.randint(100000, 110000, size = 10000)
val_12 = np.random.randint(110000, 120000, size = 10000)
val_13 = np.random.randint(120000, 130000, size = 10000)
val_14 = np.random.randint(130000, 140000, size = 10000)
val_15 = np.random.randint(140000, 150000, size = 10000)
val_16 = np.random.randint(150000, 160000, size = 10000)
val_17 = np.random.randint(160000, 170000, size = 10000)
val_18 = np.random.randint(170000, 180000, size = 10000)
val_19 = np.random.randint(180000, 190000, size = 10000)
val_20 = np.random.randint(190000, 200000, size = 10000)

# %%
#데이터 프레임 생성
data = {'특성1': val_1,
        '특성2': val_2,
        '특성3': val_3,
        '특성4': val_4,
        '특성5': val_5,
        '특성6': val_6,
        '특성7': val_7,
        '특성8': val_8,
        '특성9': val_9,
        '특성10': val_10,
        '특성11': val_11,
        '특성12': val_12,
        '특성13': val_13,
        '특성14': val_14,
        '특성15': val_15,
        '특성16': val_16,
        '특성17': val_17,
        '특성18': val_18,
        '특성19': val_19,
        '특성20': val_20}
col = ['특성1','특성2','특성3','특성4','특성5','특성6','특성7','특성8','특성9','특성10','특성11','특성12','특성13','특성14','특성15','특성16','특성17','특성18','특성19','특성20']

order_list = pd.DataFrame(data,columns = col)
order_list
# Out:
#        특성1    특성2    특성3    특성4    특성5    특성6    특성7    특성8    특성9   특성10  \
# 0     7755  10823  24568  37218  47586  50901  68712  78185  87820  91553
# 1      539  16157  24230  38055  48983  57907  67911  79938  87958  97961
# 2     1212  11222  21052  39430  45554  58311  62820  73291  88319  97598
# 3     5146  17966  24666  30031  47579  52955  69017  78702  83722  99029
# 4     1705  15405  24302  35767  49626  57034  68694  73767  85089  91719
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9995  2539  16265  22930  34055  40528  50176  60855  72604  84430  95266
# 9996  9267  10734  25954  37960  40754  52930  67263  78714  84701  90859
# 9997  7822  10091  23206  36340  40691  58962  63170  73702  86553  92218
# 9998   972  15350  20522  35316  44068  59703  65977  74190  87899  97182
# 9999  4215  18378  26801  31239  48038  55927  61653  72953  86821  98313
#
#         특성11    특성12    특성13    특성14    특성15    특성16    특성17    특성18    특성19  \
# 0     100640  119103  123026  133068  149739  153032  163163  172164  183485
# 1     107105  113098  121519  134716  140860  157068  168675  177123  185075
# 2     101667  111641  120943  135661  142113  150849  161179  177325  184764
# 3     100256  118379  124995  139424  147481  151531  168464  174766  182575
# 4     109893  117502  125402  133828  145746  157327  166750  177357  189462
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 9995  108193  115250  127050  133742  147969  152600  166190  175650  181383
# 9996  106900  118194  127941  130001  140086  159119  168562  176005  187798
# 9997  100425  116333  128595  134231  145577  150790  163381  177108  185242
# 9998  105993  117918  129290  136112  148309  150713  168517  170406  189193
# 9999  109756  118607  121494  133240  148423  159670  162094  173746  189927
#
#         특성20
# 0     198609
# 1     198285
# 2     196785
# 3     193544
# 4     194604
# ...      ...
# 9995  197162
# 9996  198210
# 9997  192135
# 9998  193238
# 9999  197194
#
# [10000 rows x 20 columns]

# %% [markdown]
# ## 4.주문 내역 내보내기. OUT PUT 값
# * DATA FRRAME ---> EXCEL

# %%
#엑셀 파일로 내보내기.
file_name ='go.xlsx'
order_list.to_excel(file_name)
print('ORDER LIST ---  successfully exported into Excel File')
# Out:
# ORDER LIST ---  successfully exported into Excel File

# %% [markdown]
# # 5. 1~4 내용 바탕으로 실전 요구사항에 더 적합한 프로그램 만들기.

# %%
#특성개수
#len(col) ------------------------------------------------------------ 변수 1 (default - 32개(적재 데이터 기준))
#특성 생성하는 함수가 필요할 수도 있음. input - 특성 수/txt 파일 output = txt파일
col = np.loadtxt('C:/Users/oryuk/OneDrive/바탕 화면/주문내역생성/특성.txt', delimiter=',', dtype=str, encoding='utf-8')
print(col)
# Out:
# ['차수' '주문일자' '매장' '매장코드' '상품코드' '상품명' '운송장번호' '운송장출력여부' '주문취소여부' '주문번호'
#  '받는이' '우편번호' '주소1' '주소2' '전화번호1' '전화번호2' '배송기재사항' '판매가' '합포여부' '예정수량'
#  '검수수량' '출력일시' '출력자' '몰구분' 'DAS여부' 'DAS차수' 'DAS지시번호' 'BOXNO' 'CELLNO'
#  '추가박스여부']

# %%
row = 10000 #default ------------------------------------------------ 변수 2 (주문개수)
#Black Box를 수정하면 주문 생성을 여러개 할 수 있음.

#name tag
alphabet = []
for i in string.ascii_uppercase:
    for j in string.ascii_uppercase:
        alphabet.append(i+j)
        
#name tag + randomint(0,10000)
data = {}
for i in range(len(col)):
    serial_num = []
    for j in range(row):
        serial_num.append(alphabet[i] + str(random.randint(0,10000)))
    data[col[i]] = serial_num
 
#DataFrame변환
order_list2 = pd.DataFrame(data,columns=col)
order_list2
# Out:
#           차수    주문일자      매장    매장코드    상품코드     상품명   운송장번호 운송장출력여부  주문취소여부  \
# 0     AA7186  AB3723  AC3499  AD7283  AE5809  AF1022  AG8780   AH526   AI397
# 1     AA6025  AB2887  AC3826  AD3835  AE4888  AF2570  AG2339  AH1559  AI3196
# 2     AA4027   AB462  AC1454  AD6037  AE7521  AF5802  AG7478  AH2924  AI4217
# 3     AA7230  AB9064  AC2216  AD2075  AE6647  AF3926  AG3330  AH9478  AI4398
# 4     AA1527  AB6329  AC8497  AD9334  AE5327  AF8227  AG8916  AH1458  AI8985
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 9995  AA9356  AB6196  AC5083   AD818  AE3434  AF7458   AG917   AH361  AI5722
# 9996  AA4573  AB6954  AC5992  AD9965    AE40  AF6991   AG657  AH1795   AI203
# 9997  AA3820  AB3894   AC103  AD2889  AE2679  AF5028  AG8373  AH4255   AI115
# 9998  AA4452  AB7297  AC1866  AD3726  AE2864  AF1948  AG7482  AH8473  AI6040
# 9999  AA5804   AB267  AC7588  AD7607  AE9582  AF1712  AG3552  AH4559  AI7714
#
#         주문번호  ...    검수수량    출력일시     출력자     몰구분   DAS여부   DAS차수 DAS지시번호  \
# 0      AJ884  ...  AU9187  AV6607  AW9406  AX3860  AY5614  AZ5096  BA8131
# 1     AJ7351  ...   AU320  AV6663   AW525  AX3121  AY1817  AZ6531   BA611
# 2      AJ666  ...  AU2229  AV3453   AW798  AX1876  AY1315  AZ8960  BA5012
# 3     AJ5962  ...  AU3035  AV9207  AW3718  AX8860  AY9050  AZ7445   BA875
# 4     AJ1991  ...  AU1825  AV3258  AW3147  AX3451  AY4439  AZ6133  BA6034
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 9995  AJ4275  ...  AU1781  AV8477  AW3187  AX5595  AY9033  AZ1189  BA5138
# 9996  AJ1781  ...  AU5050  AV8364  AW4475  AX3582   AY857  AZ9826  BA4539
# 9997   AJ957  ...  AU8498  AV4325  AW1806  AX3758  AY8400  AZ6036  BA9421
# 9998  AJ4760  ...  AU6460  AV6928  AW8346  AX4506  AY8488  AZ8935  BA2174
# 9999  AJ2881  ...  AU9640  AV8425  AW1044  AX9284  AY3434  AZ1083  BA7213
#
#        BOXNO  CELLNO  추가박스여부
# 0     BB9339  BC3389  BD3187
# 1     BB8601   BC768  BD8702
# 2     BB9338  BC9731  BD6077
# 3     BB3400  BC9073  BD6293
# 4     BB1335  BC1215  BD4759
# ...      ...     ...     ...
# 9995  BB1791  BC7176  BD6967
# 9996  BB8499  BC6117  BD2332
# 9997  BB3391  BC4261   BD114
# 9998  BB8563  BC9925  BD8366
# 9999  BB2840   BC741   BD714
#
# [10000 rows x 30 columns]

# %%
#엑셀 파일로 내보내기. -----------------------------------> 변수 3 주문 내역 Xlsx 파일이름. (default - 주문내역)
file_name ='주문내역.xlsx'
order_list2.to_excel(file_name)
print('ORDER LIST ---  successfully exported into Excel File')
# Out:
# ORDER LIST ---  successfully exported into Excel File

# %% [markdown]
# ## 6. 5과정 함축시키기.
