# %%
import pandas as pd
import numpy as np

df=pd.read_excel('/Users/yoon/Desktop/agv/202204_출고_주문번호추가.xlsx',header=1)
df1=df.rename(columns={'상품명':'상품'})
df2=df1[["상품코드","상품"]]

df2
# Out:
#                  상품코드                               상품
# 0        802980111116                        히말라야 핑크솔트
# 1       6261108117326                      샤프란 향신료 20g
# 2       5285001951833  Elegance Plus Shaving Gel 500ml
# 3       8000070021341             원두커피: 3. 라바짜 그란에스프레소
# 4           VD-MT-002        악역의 엔딩은 죽음뿐 마스킹 테이프 vol.2
# ...               ...                              ...
# 40270  RM204S007WH230                       윈드레이서 스프리트
# 40271     RM204J014GN            레이 앤 필 스터드 세트 GREEN_F
# 40272     RM204J012PC         하트 스테이트 펜던트 넥크리스 PEACH_F
# 40273     RM204J018YE            하트 크리스탈 넥크리스 YELLOW_F
# 40274             NaN                              NaN
#
# [40275 rows x 2 columns]

# %%
df3 = pd.DataFrame({
    '상품코드':df2["상품코드"],
    '상품':df2['상품'],
    'ABC': [['A', 'B', 'C'][np.random.randint(0, 3)] for i in range(len(df2))], 
    '단품가로(mm)':  [np.random.randint(1,100) for i in range(len(df2))], 
    '단품세로(mm)': [np.random.randint(1,100) for i in range(len(df2))], 
    '단품높이(mm)':  [np.random.randint(1,100) for i in range(len(df2))], 
    '중량(g)':  [np.random.randint(1, 300) for i in range(len(df2))],
    'index':[np.random.randint(1, 20) for i in range(len(df2))]
})
df3
# Out:
#                  상품코드                               상품 ABC  단품가로(mm)  \
# 0        802980111116                        히말라야 핑크솔트   A        66
# 1       6261108117326                      샤프란 향신료 20g   C        21
# 2       5285001951833  Elegance Plus Shaving Gel 500ml   B        48
# 3       8000070021341             원두커피: 3. 라바짜 그란에스프레소   A        40
# 4           VD-MT-002        악역의 엔딩은 죽음뿐 마스킹 테이프 vol.2   A        15
# ...               ...                              ...  ..       ...
# 40270  RM204S007WH230                       윈드레이서 스프리트   A        50
# 40271     RM204J014GN            레이 앤 필 스터드 세트 GREEN_F   B        39
# 40272     RM204J012PC         하트 스테이트 펜던트 넥크리스 PEACH_F   B        88
# 40273     RM204J018YE            하트 크리스탈 넥크리스 YELLOW_F   C        10
# 40274             NaN                              NaN   B        92
#
#        단품세로(mm)  단품높이(mm)  중량(g)  index
# 0            54        91     55      5
# 1            50        87    248     14
# 2            30        92     40     10
# 3            64        83    105      1
# 4            99        71    229      3
# ...         ...       ...    ...    ...
# 40270        44        61     92     15
# 40271        23        73     19     16
# 40272        59        51    186     12
# 40273        63        43     75     12
# 40274        44        44    123      8
#
# [40275 rows x 8 columns]

# %%
df3.to_excel('productInformation.xlsx')
